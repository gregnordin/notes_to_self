# %%
from manim import *
import manim
# Out:
# Manim Community v0.9.0

# %%
help(manim)
# Out:
# Help on package manim:
#
# NAME
#     manim - # flake8: noqa
#
# PACKAGE CONTENTS
#     __main__
#     _config (package)
#     animation (package)
#     camera (package)
#     cli (package)
#     communitycolors
#     constants
#     grpc (package)
#     gui (package)
#     mobject (package)
#     opengl (package)
#     plugins (package)
#     renderer (package)
#     scene (package)
#     utils (package)
#
# SUBMODULES
#     color
#     import_plugins
#     plugins_flags
#     rate_functions
#     unit
#
# DATA
#     BLACK = '#000000'
#     BLUE = '#58C4DD'
#     BLUE_A = '#C7E9F1'
#     BLUE_B = '#9CDCEB'
#     BLUE_C = '#58C4DD'
#     BLUE_D = '#29ABCA'
#     BLUE_E = '#236B8E'
#     BOLD = 'BOLD'
#     BOOK = 'BOOK'
#     CHOOSE_NUMBER_MESSAGE = '\nChoose number corresponding to desired scen...
#     CONTEXT_SETTINGS = {'help_option_names': ['-h', '--help']}
#     CTRL_VALUE = 65507
#     DARKER_GRAY = '#222222'
#     DARKER_GREY = '#222222'
#     DARK_BLUE = '#236B8E'
# ...

# %%
dir(manim)
# Out:
# ['AbstractImageMobject',
#  'AddTextLetterByLetter',
#  'AddTextWordByWord',
#  'Angle',
#  'AnimatedBoundary',
#  'Animation',
#  'AnimationGroup',
#  'AnnotationDot',
#  'AnnularSector',
#  'Annulus',
#  'ApplyComplexFunction',
#  'ApplyFunction',
#  'ApplyMatrix',
#  'ApplyMethod',
#  'ApplyPointwiseFunction',
#  'ApplyPointwiseFunctionToCenter',
#  'ApplyWave',
#  'Arc',
#  'ArcBetweenPoints',
#  'ArcBrace',
#  'ArcPolygon',
#  'ArcPolygonFromArcs',
#  'Arrow',
#  'Arrow3D',
#  'ArrowCircleFilledTip',
#  'ArrowCircleTip',
#  'ArrowSquareFilledTip',
#  'ArrowSquareTip',
#  'ArrowTip',
#  'ArrowVectorField',
#  'Axes',
#  'BLACK',
#  'BLUE',
#  'BLUE_A',
#  'BLUE_B',
#  'BLUE_C',
#  'BLUE_D',
#  'BLUE_E',
#  'BOLD',
#  'BOOK',
#  'BackgroundColoredVMobjectDisplayer',
#  'BackgroundRectangle',
#  'BarChart',
#  'Brace',
#  'BraceBetweenPoints',
#  'BraceLabel',
#  'BraceText',
#  'Broadcast',
#  'BulletedList',
#  'CHOOSE_NUMBER_MESSAGE',
#  'CONTEXT_SETTINGS',
#  'CTRL_VALUE',
# ...

# %%
# %%manim
